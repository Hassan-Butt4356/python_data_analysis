# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('elvismunica2024obweekday_export_odbc.csv')

# %%
df[df['ELVIS_STATUS']!='Delete']
# Out:
#             id            Completed  Last_page Start_language  \
# 0         5844  2024-02-21 09:11:15         82             en
# 1         5851  2024-02-21 09:11:20         82             en
# 2         5854  2024-02-21 09:11:13         82             en
# 3         5858  2024-02-21 09:11:11         82             en
# 4         5864  2024-02-21 09:11:12         82             en
# ...        ...                  ...        ...            ...
# 33859  1003222  2024-03-02 19:44:16         82             en
# 33860  1003223  2024-04-22 10:07:06         82             en
# 33861  1003224  2024-03-03 21:43:05         82             en
# 33862  1003225  2024-05-28 12:21:20         82             en
# 33863  1003226  2024-03-11 07:19:55         82             en
#
#               Date_started     Date_last_action       IP_address  \
# 0      2024-02-21 08:54:29  2024-02-21 09:11:15      12.35.79.25
# 1      2024-02-21 08:56:02  2024-02-21 09:11:20   107.77.213.142
# ...

# %%
Possible_Errors_Check
 I have implemented code to add "Possible Errors" column while generating the KINGElvis file
Elvis_Status_Check
 I have implemented the code for elvis_status for example if the Elvis_Status is Delete then do not include those records in KINGElvis and in the further
process like Flag Files.
origin_destination and transfer_points checks
  I have developed a script to address cases where the origin and destination are same or the distance between 
the origin and destination is less than 0.25 miles, and where transfer points are either missing or a transfer route 
is selected without a corresponding transfer point. This script aims to resolve issues where some records are not flagged correctly,
specifically when transfer points are missing or the distance between the origin and destination is less than 0.25 miles.
Boarding/Alighting distance from Survey Line
   This check already implemented in the OD_Distance check in which we are checking the distance between Origin to first_boarding and 
Last_alighting to Destination so no need to implement that check
