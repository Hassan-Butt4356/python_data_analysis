# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('reviewtool_20240821_LAGUARDIA_combinedflags.csv')
df.head()
# Out:
#    Elvis_Date  elvis_id 1st Cleaner  ORIGIN_ADDRESS_LAT  ORIGIN_ADDRESS_LONG  \
# 0  2024-08-21       514        Test           40.726545           -73.941539
# 1  2024-08-21       522     HereAPI           40.773656           -73.959860
# 2  2024-08-21       524        Test           40.772924           -73.872198
# 3  2024-08-21       525        Test           40.772924           -73.872198
# 4  2024-08-21       528        Test           40.706672           -73.960228
#
#    DESTIN_ADDRESS_LAT  DESTIN_ADDRESS_LONG  STOP_ON_LAT  STOP_ON_LONG  \
# 0           40.772924           -73.872198    40.768790    -73.910815
# 1           40.772924           -73.872198    40.801818    -73.967642
# 2           40.772924           -73.872198    40.772924    -73.872198
# 3           40.747929           -73.943983    40.772924    -73.872198
# 4           40.772924           -73.872198    40.746543    -73.890686
#
#    STOP_OFF_LAT  ...  Stops_Status Test_Status Traditional_Check  \
# ...

# %%
df=df[df['1st Cleaner']=='HereAPI']
df.head()
# Out:
#     Elvis_Date  elvis_id 1st Cleaner  ORIGIN_ADDRESS_LAT  ORIGIN_ADDRESS_LONG  \
# 1   2024-08-21       522     HereAPI           40.773656           -73.959860
# 6   2024-08-21       531     HereAPI           40.786494           -73.838960
# 9   2024-08-21       538     HereAPI           40.747282           -73.926862
# 20  2024-08-21       600     HereAPI           40.767009           -73.867043
# 21  2024-08-21       605     HereAPI           40.772924           -73.872198
#
#     DESTIN_ADDRESS_LAT  DESTIN_ADDRESS_LONG  STOP_ON_LAT  STOP_ON_LONG  \
# 1            40.772924           -73.872198    40.801818    -73.967642
# 6            40.772924           -73.872198    40.770289    -73.864375
# 9            40.772924           -73.872198    40.770459    -73.917778
# 20           40.772924           -73.872198    40.770289    -73.864375
# 21           40.704189           -73.894813    40.772924    -73.872198
#
#     STOP_OFF_LAT  ...  Stops_Status Test_Status Traditional_Check  \
# ...

# %%
df[df['elvis_id']<650].shape
# Out:
# (54, 46)

# %%
df[(df['elvis_id']>=700)&(df['elvis_id']<820)].shape
# Out:
# (89, 46)

# %%
df[(df['elvis_id']>=900)&(df['elvis_id']<1051)].shape
# Out:
# (119, 46)

# %%
df[(df['elvis_id']>=900)&(df['elvis_id']<1000)].shape
# Out:
# (81, 46)

# %%
df[df['elvis_id']<1259].shape
# Out:
# (443, 46)

# %%
df[df['elvis_id']<1259].shape
