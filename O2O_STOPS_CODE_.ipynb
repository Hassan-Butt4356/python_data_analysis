# %%
import pandas as pd
import numpy as np
from datetime import datetime
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# I’ve implemented code to generate the O2O_STOPS sheet similarly to the original one.
# Here's how it works:
# I extracted the line name from the database (e.g., "BLUE_LINE_NB_ON" became "BlueLine").
# From the details_file (sheet "STOPS"), I also extracted line names (e.g., "VTA_2_GreenLine_00" became "GreenLine").
# I then compared the line names and stop names from both files.
# If they matched, I included information such as ‘seq_fixed,’ ‘ETC_STOP_NAME,’ ‘ETC_STOP_ID,’ ‘ETC_ROUTE_ID,’ and ‘ETC_ROUTE_NAME’ from the database to build the final output.

# %%
def check_all_code_columns(df, columns_to_check):
    # Function to clean a string by removing underscores and square brackets and converting to lowercase
    def clean_string(s):
        return s.replace('_', '').replace('[', '').replace(']', '').replace(' ','').replace('#','').lower()

    # Clean and convert all column names in df to lowercase for case-insensitive comparison
    df_columns_lower = [clean_string(column) for column in df.columns]

    # Clean and convert the columns_to_check list to lowercase for case-insensitive comparison
    columns_to_check_lower = [clean_string(column) for column in columns_to_check]

    # Use a list comprehension to filter columns
    matching_columns = [column for column in df_columns_lower if "code" in column]

    return matching_columns


def check_all_characters_present(df, columns_to_check):
    # Function to clean a string by removing underscores and square brackets and converting to lowercase
    def clean_string(s):
        return s.replace('_', '').replace('[', '').replace(']', '').replace(' ','').replace('#','').lower()

    # Clean and convert all column names in df to lowercase for case-insensitive comparison
    df_columns_lower = [clean_string(column) for column in df.columns]

    # Clean and convert the columns_to_check list to lowercase for case-insensitive comparison
    columns_to_check_lower = [clean_string(column) for column in columns_to_check]

    # Use a list comprehension to filter columns
    matching_columns = [column for column in df.columns if clean_string(column) in columns_to_check_lower]

    return matching_columns

def clean_string(s):
    return s.replace(':', '').replace('-', '').replace('_', '').replace('[', '').replace(']', '').replace(' ','').replace('#','').lower()

# %%
project_name='VTA'

df=pd.read_csv('vtaca2024rail_o2o_export_odbc.csv')

# df=df[df['INTERV_INIT']!='999']

detail_df=pd.read_excel('details_vta_CA_od_excel (1).xlsx',sheet_name='STOPS')

# %%
detail_df.columns
# Out:
# Index(['agency', 'gtfs_ver', 'gtfs_date', 'route_short_name',
#        'route_long_name', 'direction_id', 'route_dir', 'seq_fixed', 'stop_id',
#        'stop_name', 'stop_lat', 'stop_lon', 'stop_lat6', 'stop_lon6',
#        'ETC_STOP_ID', 'ETC_STOP_NAME', 'notes', 'ETC_ROUTE_ID',
#        'ETC_ROUTE_NAME'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['id', 'Completed', 'Last_page', 'Start_language', 'Date_started',
#        'Date_last_action', 'IP_address', 'Referring_URL', '_INTERV_INIT',
#        'TIME_ADJUST', 'ORIGRESPID', 'ROUTE_SURVEYED_Code_', 'ROUTE_SURVEYED',
#        'BLUE_LINE_NB_ON_Code_', 'BLUE_LINE_NB_ON', 'BLUE_LINE_NB_OFF_Code_',
#        'BLUE_LINE_NB_OFF', 'BLUE_LIME_SB_ON_Code_', 'BLUE_LIME_SB_ON',
#        'BLUE_LIME_SB_OFF_Code_', 'BLUE_LIME_SB_OFF', 'GREEN_LINE_NB_ON_Code_',
#        'GREEN_LINE_NB_ON', 'GREEN_LINE_NB_OFF_Code_', 'GREEN_LINE_NB_OFF',
#        'GREEN_LINE_SB_ON_Code_', 'GREEN_LINE_SB_ON', 'GREEN_LINE_SB_OFF_Code_',
#        'GREEN_LINE_SB_OFF', 'ORANGE_LINE_EB_ON_Code_', 'ORANGE_LINE_EB_ON',
#        'ORANGE_LINE_EB_OFF_Code_', 'ORANGE_LINE_EB_OFF',
#        'ORANGE_LINE_WB_ON_Code_', 'ORANGE_LINE_WB_ON',
#        'ORANGE_LINE_WB_OFF_Code_', 'ORANGE_LINE_WB_OFF', 'TIME_BOARDED_Code_',
#        'TIME_BOARDED', 'RESTART_URL'],
#       dtype='object')

# %%
code_columns=check_all_code_columns(df,df.columns)

code_columns=check_all_characters_present(df,code_columns)
code_columns
# Out:
# ['ROUTE_SURVEYED_Code_',
#  'BLUE_LINE_NB_ON_Code_',
#  'BLUE_LINE_NB_OFF_Code_',
#  'BLUE_LIME_SB_ON_Code_',
#  'BLUE_LIME_SB_OFF_Code_',
#  'GREEN_LINE_NB_ON_Code_',
#  'GREEN_LINE_NB_OFF_Code_',
#  'GREEN_LINE_SB_ON_Code_',
#  'GREEN_LINE_SB_OFF_Code_',
#  'ORANGE_LINE_EB_ON_Code_',
#  'ORANGE_LINE_EB_OFF_Code_',
#  'ORANGE_LINE_WB_ON_Code_',
#  'ORANGE_LINE_WB_OFF_Code_',
#  'TIME_BOARDED_Code_']

# %%
detail_df['LineName']=detail_df['ETC_ROUTE_ID'].apply(lambda x: str(x).split('_')[2])

# %%
'VTA_2_GreenLine_00'.split('_')[2]
# Out:
# 'GreenLine'

# %%
detail_df.query('LineName=="GreenLine"')
# Out:
#      agency  gtfs_ver gtfs_date route_short_name             route_long_name  \
# 4388    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4389    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4390    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4391    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4392    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4393    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4394    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4395    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4396    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4397    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4398    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4399    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4400    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4401    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4402    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4403    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4404    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4405    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4406    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4407    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4408    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4409    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4410    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4411    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4412    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4413    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4414    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4415    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4416    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4417    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4418    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4419    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4420    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4421    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4422    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4423    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4424    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4425    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4426    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4427    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4428    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4429    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4430    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4431    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4432    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4433    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4434    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4435    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4436    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4437    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4438    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4439    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4440    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4441    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
# 4442    VTA         2  8/7/2024        GreenLine  Old Ironsides - Winchester
#
#       direction_id    route_dir  seq_fixed  stop_id  \
# 4388             0  GreenLine_0          1     5380
# 4389             0  GreenLine_0          2     5379
# 4390             0  GreenLine_0          3     5378
# 4391             0  GreenLine_0          4     5377
# 4392             0  GreenLine_0          5     5376
# 4393             0  GreenLine_0          6     5375
# 4394             0  GreenLine_0          7     5374
# 4395             0  GreenLine_0          8     5388
# 4396             0  GreenLine_0          9     4746
# 4397             0  GreenLine_0         10     4747
# 4398             0  GreenLine_0         11     4748
# 4399             0  GreenLine_0         12     4749
# 4400             0  GreenLine_0         13     4750
# 4401             0  GreenLine_0         14     4751
# 4402             0  GreenLine_0         15     4752
# 4403             0  GreenLine_0         16     4753
# 4404             0  GreenLine_0         17     4754
# 4405             0  GreenLine_0         18     4755
# 4406             0  GreenLine_0         19     4756
# 4407             0  GreenLine_0         20     4757
# 4408             0  GreenLine_0         21     4758
# 4409             0  GreenLine_0         22     4759
# 4410             0  GreenLine_0         23     4801
# 4411             0  GreenLine_0         24     4807
# 4412             0  GreenLine_0         25     4808
# 4413             0  GreenLine_0         26     4809
# 4414             0  GreenLine_0         27     4810
# 4415             0  GreenLine_0         28     5866
# 4416             1  GreenLine_1          1     4797
# 4417             1  GreenLine_1          2     4798
# 4418             1  GreenLine_1          3     4799
# 4419             1  GreenLine_1          4     4800
# 4420             1  GreenLine_1          5     4761
# 4421             1  GreenLine_1          6     4762
# 4422             1  GreenLine_1          7     4763
# 4423             1  GreenLine_1          8     4764
# 4424             1  GreenLine_1          9     4765
# 4425             1  GreenLine_1         10     4766
# 4426             1  GreenLine_1         11     4767
# 4427             1  GreenLine_1         12     4768
# 4428             1  GreenLine_1         13     4769
# 4429             1  GreenLine_1         14     4770
# 4430             1  GreenLine_1         15     4771
# 4431             1  GreenLine_1         16     4772
# 4432             1  GreenLine_1         17     4773
# 4433             1  GreenLine_1         18     4774
# 4434             1  GreenLine_1         19     4775
# 4435             1  GreenLine_1         20     5389
# 4436             1  GreenLine_1         21     5381
# 4437             1  GreenLine_1         22     5382
# 4438             1  GreenLine_1         23     5383
# 4439             1  GreenLine_1         24     5384
# 4440             1  GreenLine_1         25     5385
# 4441             1  GreenLine_1         26     5386
# 4442             1  GreenLine_1         27     5387
#
#                        stop_name   stop_lat    stop_lon  stop_lat6  \
# 4388          Winchester Station  37.279610 -121.947906  37.279610
# 4389            Campbell Station  37.285900 -121.943027  37.285900
# 4390            Hamilton Station  37.294064 -121.936167  37.294064
# 4391              Bascom Station  37.299851 -121.929830  37.299851
# 4392           Fruitdale Station  37.310482 -121.918017  37.310482
# 4393                Race Station  37.317567 -121.910314  37.317567
# 4394             Diridon Station  37.328947 -121.903511  37.328947
# 4395        San Fernando Station  37.330367 -121.898116  37.330367
# 4396   Convention Center Station  37.330168 -121.889754  37.330168
# 4397         San Antonio Station  37.332782 -121.887979  37.332782
# 4398         Santa Clara Station  37.335924 -121.890354  37.335924
# 4399         Saint James Station  37.338402 -121.892183  37.338402
# 4400      Japantown/Ayer Station  37.345557 -121.897559  37.345557
# 4401        Civic Center Station  37.352016 -121.902434  37.352016
# 4402                Gish Station  37.362544 -121.910160  37.362544
# 4403       Metro/Airport Station  37.370364 -121.915990  37.370364
# 4404              Karina Station  37.376278 -121.920405  37.376278
# 4405           Component Station  37.383483 -121.925777  37.383483
# 4406         Bonaventura Station  37.388749 -121.929742  37.388749
# 4407             Orchard Station  37.395730 -121.934869  37.395730
# 4408          River Oaks Station  37.402847 -121.940027  37.402847
# 4409              Tasman Station  37.408669 -121.944463  37.408669
# 4410           Baypointe Station  37.410877 -121.941523  37.410877
# 4411            Champion Station  37.409423 -121.952616  37.409423
# 4412           Lick Mill Station  37.407616 -121.963679  37.407616
# 4413       Great America Station  37.403468 -121.974908  37.403468
# 4414       Old Ironsides Station  37.403309 -121.979862  37.403309
# 4415  PATRICK HENRY POCKET TRACK  37.403489 -121.984251  37.403489
# 4416       Old Ironsides Station  37.403299 -121.978871  37.403299
# 4417       Great America Station  37.403555 -121.974058  37.403555
# 4418           Lick Mill Station  37.407795 -121.962925  37.407795
# 4419            Champion Station  37.408898 -121.951936  37.408898
# 4420           Baypointe Station  37.410438 -121.942311  37.410438
# 4421              Tasman Station  37.408056 -121.943998  37.408056
# 4422          River Oaks Station  37.401188 -121.938972  37.401188
# 4423             Orchard Station  37.394082 -121.933837  37.394082
# 4424         Bonaventura Station  37.387197 -121.928715  37.387197
# 4425           Component Station  37.381937 -121.924755  37.381937
# 4426              Karina Station  37.374609 -121.919317  37.374609
# 4427       Metro/Airport Station  37.368664 -121.914883  37.368664
# 4428                Gish Station  37.360938 -121.909099  37.360938
# 4429        Civic Center Station  37.351380 -121.901956  37.351380
# 4430      Japantown/Ayer Station  37.344964 -121.897116  37.344964
# 4431         Saint James Station  37.338358 -121.890805  37.338358
# 4432         Santa Clara Station  37.335796 -121.888910  37.335796
# 4433         San Antonio Station  37.333481 -121.887188  37.333481
# 4434   Convention Center Station  37.329809 -121.890538  37.329809
# 4435        San Fernando Station  37.330248 -121.899045  37.330248
# 4436             Diridon Station  37.328296 -121.903588  37.328296
# 4437                Race Station  37.317155 -121.910753  37.317155
# 4438           Fruitdale Station  37.310122 -121.918483  37.310122
# 4439              Bascom Station  37.299467 -121.930304  37.299467
# 4440            Hamilton Station  37.293691 -121.936576  37.293691
# 4441            Campbell Station  37.285483 -121.943395  37.285483
# 4442          Winchester Station  37.279178 -121.948307  37.279178
#
#        stop_lon6              ETC_STOP_ID               ETC_STOP_NAME  notes  \
# 4388 -121.947906  VTA_2_GreenLine_00_5380          Winchester Station    NaN
# 4389 -121.943027  VTA_2_GreenLine_00_5379            Campbell Station    NaN
# 4390 -121.936167  VTA_2_GreenLine_00_5378            Hamilton Station    NaN
# 4391 -121.929830  VTA_2_GreenLine_00_5377              Bascom Station    NaN
# 4392 -121.918017  VTA_2_GreenLine_00_5376           Fruitdale Station    NaN
# 4393 -121.910314  VTA_2_GreenLine_00_5375                Race Station    NaN
# 4394 -121.903511  VTA_2_GreenLine_00_5374             Diridon Station    NaN
# 4395 -121.898116  VTA_2_GreenLine_00_5388        San Fernando Station    NaN
# 4396 -121.889754  VTA_2_GreenLine_00_4746   Convention Center Station    NaN
# 4397 -121.887979  VTA_2_GreenLine_00_4747         San Antonio Station    NaN
# 4398 -121.890354  VTA_2_GreenLine_00_4748         Santa Clara Station    NaN
# 4399 -121.892183  VTA_2_GreenLine_00_4749         Saint James Station    NaN
# 4400 -121.897559  VTA_2_GreenLine_00_4750      Japantown/Ayer Station    NaN
# 4401 -121.902434  VTA_2_GreenLine_00_4751        Civic Center Station    NaN
# 4402 -121.910160  VTA_2_GreenLine_00_4752                Gish Station    NaN
# 4403 -121.915990  VTA_2_GreenLine_00_4753       Metro/Airport Station    NaN
# 4404 -121.920405  VTA_2_GreenLine_00_4754              Karina Station    NaN
# 4405 -121.925777  VTA_2_GreenLine_00_4755           Component Station    NaN
# 4406 -121.929742  VTA_2_GreenLine_00_4756         Bonaventura Station    NaN
# 4407 -121.934869  VTA_2_GreenLine_00_4757             Orchard Station    NaN
# 4408 -121.940027  VTA_2_GreenLine_00_4758          River Oaks Station    NaN
# 4409 -121.944463  VTA_2_GreenLine_00_4759              Tasman Station    NaN
# 4410 -121.941523  VTA_2_GreenLine_00_4801           Baypointe Station    NaN
# 4411 -121.952616  VTA_2_GreenLine_00_4807            Champion Station    NaN
# 4412 -121.963679  VTA_2_GreenLine_00_4808           Lick Mill Station    NaN
# 4413 -121.974908  VTA_2_GreenLine_00_4809       Great America Station    NaN
# 4414 -121.979862  VTA_2_GreenLine_00_4810       Old Ironsides Station    NaN
# 4415 -121.984251  VTA_2_GreenLine_00_5866  PATRICK HENRY POCKET TRACK    NaN
# 4416 -121.978871  VTA_2_GreenLine_01_4797       Old Ironsides Station    NaN
# 4417 -121.974058  VTA_2_GreenLine_01_4798       Great America Station    NaN
# 4418 -121.962925  VTA_2_GreenLine_01_4799           Lick Mill Station    NaN
# 4419 -121.951936  VTA_2_GreenLine_01_4800            Champion Station    NaN
# 4420 -121.942311  VTA_2_GreenLine_01_4761           Baypointe Station    NaN
# 4421 -121.943998  VTA_2_GreenLine_01_4762              Tasman Station    NaN
# 4422 -121.938972  VTA_2_GreenLine_01_4763          River Oaks Station    NaN
# 4423 -121.933837  VTA_2_GreenLine_01_4764             Orchard Station    NaN
# 4424 -121.928715  VTA_2_GreenLine_01_4765         Bonaventura Station    NaN
# 4425 -121.924755  VTA_2_GreenLine_01_4766           Component Station    NaN
# 4426 -121.919317  VTA_2_GreenLine_01_4767              Karina Station    NaN
# 4427 -121.914883  VTA_2_GreenLine_01_4768       Metro/Airport Station    NaN
# 4428 -121.909099  VTA_2_GreenLine_01_4769                Gish Station    NaN
# 4429 -121.901956  VTA_2_GreenLine_01_4770        Civic Center Station    NaN
# 4430 -121.897116  VTA_2_GreenLine_01_4771      Japantown/Ayer Station    NaN
# 4431 -121.890805  VTA_2_GreenLine_01_4772         Saint James Station    NaN
# 4432 -121.888910  VTA_2_GreenLine_01_4773         Santa Clara Station    NaN
# 4433 -121.887188  VTA_2_GreenLine_01_4774         San Antonio Station    NaN
# 4434 -121.890538  VTA_2_GreenLine_01_4775   Convention Center Station    NaN
# 4435 -121.899045  VTA_2_GreenLine_01_5389        San Fernando Station    NaN
# 4436 -121.903588  VTA_2_GreenLine_01_5381             Diridon Station    NaN
# 4437 -121.910753  VTA_2_GreenLine_01_5382                Race Station    NaN
# 4438 -121.918483  VTA_2_GreenLine_01_5383           Fruitdale Station    NaN
# 4439 -121.930304  VTA_2_GreenLine_01_5384              Bascom Station    NaN
# 4440 -121.936576  VTA_2_GreenLine_01_5385            Hamilton Station    NaN
# 4441 -121.943395  VTA_2_GreenLine_01_5386            Campbell Station    NaN
# 4442 -121.948307  VTA_2_GreenLine_01_5387          Winchester Station    NaN
#
#             ETC_ROUTE_ID                                     ETC_ROUTE_NAME  \
# 4388  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4389  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4390  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4391  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4392  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4393  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4394  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4395  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4396  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4397  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4398  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4399  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4400  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4401  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4402  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4403  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4404  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4405  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4406  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4407  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4408  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4409  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4410  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4411  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4412  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4413  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4414  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4415  VTA_2_GreenLine_00  Green Line - Old Ironsides - Winchester [North...
# 4416  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4417  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4418  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4419  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4420  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4421  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4422  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4423  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4424  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4425  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4426  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4427  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4428  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4429  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4430  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4431  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4432  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4433  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4434  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4435  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4436  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4437  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4438  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4439  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4440  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4441  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
# 4442  VTA_2_GreenLine_01  Green Line - Old Ironsides - Winchester [South...
#
#        LineName
# 4388  GreenLine
# 4389  GreenLine
# 4390  GreenLine
# 4391  GreenLine
# 4392  GreenLine
# 4393  GreenLine
# 4394  GreenLine
# 4395  GreenLine
# 4396  GreenLine
# 4397  GreenLine
# 4398  GreenLine
# 4399  GreenLine
# 4400  GreenLine
# 4401  GreenLine
# 4402  GreenLine
# 4403  GreenLine
# 4404  GreenLine
# 4405  GreenLine
# 4406  GreenLine
# 4407  GreenLine
# 4408  GreenLine
# 4409  GreenLine
# 4410  GreenLine
# 4411  GreenLine
# 4412  GreenLine
# 4413  GreenLine
# 4414  GreenLine
# 4415  GreenLine
# 4416  GreenLine
# 4417  GreenLine
# 4418  GreenLine
# 4419  GreenLine
# 4420  GreenLine
# 4421  GreenLine
# 4422  GreenLine
# 4423  GreenLine
# 4424  GreenLine
# 4425  GreenLine
# 4426  GreenLine
# 4427  GreenLine
# 4428  GreenLine
# 4429  GreenLine
# 4430  GreenLine
# 4431  GreenLine
# 4432  GreenLine
# 4433  GreenLine
# 4434  GreenLine
# 4435  GreenLine
# 4436  GreenLine
# 4437  GreenLine
# 4438  GreenLine
# 4439  GreenLine
# 4440  GreenLine
# 4441  GreenLine
# 4442  GreenLine

# %%
detail_df[['LineName']]
# Out:
#         LineName
# 0             20
# 1             20
# 2             20
# 3             20
# 4             20
# ...          ...
# 5057  School288M
# 5058       SCVMC
# 5059       SCVMC
# 5060       SCVMC
# 5061       SCVMC
#
# [5062 rows x 1 columns]

# %%
df[[
 'BLUE_LINE_NB_ON_Code_',
 'BLUE_LINE_NB_OFF_Code_',
 'BLUE_LIME_SB_ON_Code_',
 'BLUE_LIME_SB_OFF_Code_',
 'GREEN_LINE_NB_ON_Code_',
 'GREEN_LINE_NB_OFF_Code_',
 'GREEN_LINE_SB_ON_Code_',
 'GREEN_LINE_SB_OFF_Code_',
 'ORANGE_LINE_EB_ON_Code_',
 'ORANGE_LINE_EB_OFF_Code_',
 'ORANGE_LINE_WB_ON_Code_',
 'ORANGE_LINE_WB_OFF_Code_',]]
# Out:
#       BLUE_LINE_NB_ON_Code_  BLUE_LINE_NB_OFF_Code_  BLUE_LIME_SB_ON_Code_  \
# 0                       NaN                     NaN                    NaN
# 1                       1.0                     9.0                    NaN
# 2                       NaN                     NaN                    4.0
# 3                       NaN                     NaN                    NaN
# 4                       NaN                     NaN                    NaN
# ...                     ...                     ...                    ...
# 6834                   22.0                    26.0                    NaN
# 6835                    NaN                     NaN                    NaN
# 6836                    NaN                     NaN                    NaN
# 6837                    NaN                     NaN                    NaN
# 6838                    NaN                     NaN                    NaN
#
#       BLUE_LIME_SB_OFF_Code_  GREEN_LINE_NB_ON_Code_  GREEN_LINE_NB_OFF_Code_  \
# 0                        NaN                     1.0                      1.0
# 1                        NaN                     NaN                      NaN
# 2                        8.0                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
# ...                      ...                     ...                      ...
# 6834                     NaN                     NaN                      NaN
# 6835                     NaN                    23.0                     26.0
# 6836                     NaN                    23.0                     25.0
# 6837                     NaN                    22.0                     26.0
# 6838                     NaN                    23.0                     26.0
#
#       GREEN_LINE_SB_ON_Code_  GREEN_LINE_SB_OFF_Code_  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 6834                     NaN                      NaN
# 6835                     NaN                      NaN
# 6836                     NaN                      NaN
# 6837                     NaN                      NaN
# 6838                     NaN                      NaN
#
#       ORANGE_LINE_EB_ON_Code_  ORANGE_LINE_EB_OFF_Code_  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                        13.0                      16.0
# 4                        17.0                      26.0
# ...                       ...                       ...
# 6834                      NaN                       NaN
# 6835                      NaN                       NaN
# 6836                      NaN                       NaN
# 6837                      NaN                       NaN
# 6838                      NaN                       NaN
#
#       ORANGE_LINE_WB_ON_Code_  ORANGE_LINE_WB_OFF_Code_
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ...                       ...                       ...
# 6834                      NaN                       NaN
# 6835                      NaN                       NaN
# 6836                      NaN                       NaN
# 6837                      NaN                       NaN
# 6838                      NaN                       NaN
#
# [6839 rows x 12 columns]

# %%
def get_line_name(row):
    if pd.notna(row['BLUE_LINE_NB_ON_Code_']) or pd.notna(row['BLUE_LINE_NB_OFF_Code_']):
        return 'BlueLine'
    elif pd.notna(row['BLUE_LIME_SB_ON_Code_']) or pd.notna(row['BLUE_LIME_SB_OFF_Code_']):
        return 'BlueLine'
    elif pd.notna(row['GREEN_LINE_NB_ON_Code_']) or pd.notna(row['GREEN_LINE_NB_OFF_Code_']):
        return 'GreenLine'
    elif pd.notna(row['GREEN_LINE_SB_ON_Code_']) or pd.notna(row['GREEN_LINE_SB_OFF_Code_']):
        return 'GreenLine'
    elif pd.notna(row['ORANGE_LINE_EB_ON_Code_']) or pd.notna(row['ORANGE_LINE_EB_OFF_Code_']):
        return 'OrangeLine'
    elif pd.notna(row['ORANGE_LINE_WB_ON_Code_']) or pd.notna(row['ORANGE_LINE_WB_OFF_Code_']):
        return 'OrangeLine'
    else:
        return 'Unknown'

# %%
def get_line_name(row):
    if pd.notna(row['BLUE_LINE_NB_ON_Code_']) or pd.notna(row['BLUE_LINE_NB_OFF_Code_']):
        return 'BlueLine', row['BLUE_LINE_NB_ON']
    elif pd.notna(row['BLUE_LIME_SB_ON_Code_']) or pd.notna(row['BLUE_LIME_SB_OFF_Code_']):
        return 'BlueLine', row['BLUE_LIME_SB_ON']
    elif pd.notna(row['GREEN_LINE_NB_ON_Code_']) or pd.notna(row['GREEN_LINE_NB_OFF_Code_']):
        return 'GreenLine', row['GREEN_LINE_NB_ON']
    elif pd.notna(row['GREEN_LINE_SB_ON_Code_']) or pd.notna(row['GREEN_LINE_SB_OFF_Code_']):
        return 'GreenLine', row['GREEN_LINE_SB_ON']
    elif pd.notna(row['ORANGE_LINE_EB_ON_Code_']) or pd.notna(row['ORANGE_LINE_EB_OFF_Code_']):
        return 'OrangeLine', row['ORANGE_LINE_EB_ON']
    elif pd.notna(row['ORANGE_LINE_WB_ON_Code_']) or pd.notna(row['ORANGE_LINE_WB_OFF_Code_']):
        return 'OrangeLine', row['ORANGE_LINE_WB_ON']
    else:
        return 'Unknown', ''

# %%
def get_line_name(row):
    if pd.notna(row['BLUE_LINE_NB_ON_Code_']) or pd.notna(row['BLUE_LINE_NB_OFF_Code_']):
        on_stop = row['BLUE_LINE_NB_ON'] if pd.notna(row['BLUE_LINE_NB_ON']) else ''
        off_stop = row['BLUE_LINE_NB_OFF'] if pd.notna(row['BLUE_LINE_NB_OFF']) else ''
        return 'BlueLine', on_stop , off_stop
    elif pd.notna(row['BLUE_LIME_SB_ON_Code_']) or pd.notna(row['BLUE_LIME_SB_OFF_Code_']):
        on_stop = row['BLUE_LIME_SB_ON'] if pd.notna(row['BLUE_LIME_SB_ON']) else ''
        off_stop = row['BLUE_LIME_SB_OFF'] if pd.notna(row['BLUE_LIME_SB_OFF']) else ''
        return 'BlueLine', on_stop, off_stop
    elif pd.notna(row['GREEN_LINE_NB_ON_Code_']) or pd.notna(row['GREEN_LINE_NB_OFF_Code_']):
        on_stop = row['GREEN_LINE_NB_ON'] if pd.notna(row['GREEN_LINE_NB_ON']) else ''
        off_stop = row['GREEN_LINE_NB_OFF'] if pd.notna(row['GREEN_LINE_NB_OFF']) else ''
        return 'GreenLine', on_stop , off_stop
    elif pd.notna(row['GREEN_LINE_SB_ON_Code_']) or pd.notna(row['GREEN_LINE_SB_OFF_Code_']):
        on_stop = row['GREEN_LINE_SB_ON'] if pd.notna(row['GREEN_LINE_SB_ON']) else ''
        off_stop = row['GREEN_LINE_SB_OFF'] if pd.notna(row['GREEN_LINE_SB_OFF']) else ''
        return 'GreenLine', on_stop, off_stop
    elif pd.notna(row['ORANGE_LINE_EB_ON_Code_']) or pd.notna(row['ORANGE_LINE_EB_OFF_Code_']):
        on_stop = row['ORANGE_LINE_EB_ON'] if pd.notna(row['ORANGE_LINE_EB_ON']) else ''
        off_stop = row['ORANGE_LINE_EB_OFF'] if pd.notna(row['ORANGE_LINE_EB_OFF']) else ''
        return 'OrangeLine', on_stop , off_stop
    elif pd.notna(row['ORANGE_LINE_WB_ON_Code_']) or pd.notna(row['ORANGE_LINE_WB_OFF_Code_']):
        on_stop = row['ORANGE_LINE_WB_ON'] if pd.notna(row['ORANGE_LINE_WB_ON']) else ''
        off_stop = row['ORANGE_LINE_WB_OFF'] if pd.notna(row['ORANGE_LINE_WB_OFF']) else ''
        return 'OrangeLine', on_stop , off_stop
    else:
        return 'Unknown', '', ''

# %%
code_columns[1:-1]
# Out:
# ['BLUE_LINE_NB_ON_Code_',
#  'BLUE_LINE_NB_OFF_Code_',
#  'BLUE_LIME_SB_ON_Code_',
#  'BLUE_LIME_SB_OFF_Code_',
#  'GREEN_LINE_NB_ON_Code_',
#  'GREEN_LINE_NB_OFF_Code_',
#  'GREEN_LINE_SB_ON_Code_',
#  'GREEN_LINE_SB_OFF_Code_',
#  'ORANGE_LINE_EB_ON_Code_',
#  'ORANGE_LINE_EB_OFF_Code_',
#  'ORANGE_LINE_WB_ON_Code_',
#  'ORANGE_LINE_WB_OFF_Code_']

# %%
# df['LineNameDatabase'] = df[code_columns[1:-1]].apply(get_line_name, axis=1)

# Apply the function to create the new columns
df[['LineNameDatabase', 'ON_STOP_NAME','OFF_STOP_NAME']] = df.apply(get_line_name, axis=1, result_type='expand')

# %%
df[['LineNameDatabase', 'ON_STOP_NAME','OFF_STOP_NAME']]
# Out:
#      LineNameDatabase   ON_STOP_NAME  OFF_STOP_NAME
# 0           GreenLine     Winchester     Winchester
# 1            BlueLine   Santa Teresa         Tamien
# 2            BlueLine        Orchard  Metro/Airport
# 3          OrangeLine  Great America      Baypointe
# 4          OrangeLine      Cisco Way      Alum Rock
# ...               ...            ...            ...
# 6834         BlueLine    Bonaventure      Baypointe
# 6835        GreenLine       Champion  Old Ironsides
# 6836        GreenLine       Champion  Great America
# 6837        GreenLine         Tasman  Old Ironsides
# 6838        GreenLine       Champion  Old Ironsides
#
# [6839 rows x 3 columns]

# %%
unique_line_names=df['LineNameDatabase'].unique()
unique_line_names
# Out:
# array(['GreenLine', 'BlueLine', 'OrangeLine'], dtype=object)

# %%
unique_on_stop_names=df['ON_STOP_NAME'].unique()
unique_off_stop_names=df['OFF_STOP_NAME'].unique()
unique_on_stop_names,unique_off_stop_names
# Out:
# (array(['Winchester', 'Santa Teresa', 'Orchard', 'Great America',
#         'Cisco Way', 'Champion', 'Alder', 'Tasman', 'Bonaventure',
#         'Hamilton', 'Baypointe', 'Gish', 'River Oaks', 'Mountainview',
#         'Metro/Airport', 'Great Mall', 'Middlefield', 'Civic Center',
#         'Japantown/Ayer', 'Milipitas', 'St. James', 'Alum Rock',
#         'Old Ironsides', 'Santa Clara', 'Lick Kill', 'Penitencia Creek',
#         'Convention Center', 'McKee', 'Children’s Discovery Museum',
#         'Virginia', 'Tamien', 'Curtner', 'Capitol', 'Paseo de San Antonio',
#         'Snell', 'Cottle', 'Ohlone/Chynoweth', 'Paseo de San Antonion',
#         'Branham', 'Karina', 'San Jose Diridon', 'San Fernando',
#         'Blossom Hill', 'Berryessa', 'Hostetter', 'Fruitdale', 'Bascom',
#         'Downtown Campbell', 'Cropley', 'Race', 'Lick Mill', 'Fair Oaks',
#         'Crossman', 'Whisman', 'Vienna', 'Reamwood', 'Component',
#         'Moffett Park', 'Lockheed Martin', 'Bayshore/NASA', 'Borregas'],
#        dtype=object),
#  array(['Winchester', 'Tamien', 'Metro/Airport', 'Baypointe', 'Alum Rock',
#         'McKee', 'Great Mall', 'Milipitas', 'Karina', 'Hamilton',
#         'Santa Clara', 'Bonaventure', 'Paseo de San Antonio', 'Component',
#         'Santa Teresa', 'Virginia', 'Cottle', 'Cisco Way', 'St. James',
#         'Convention Center', 'Berryessa', 'Hostetter', 'Orchard',
#         'Ohlone/Chynoweth', 'Curtner', 'Branham', 'Capitol',
#         'Blossom Hill', 'San Jose Diridon', 'Civic Center', 'Borregas',
#         'Japantown/Ayer', 'Paseo de San Antonion',
#         'Children’s Discovery Museum', 'San Fernando', 'Champion',
#         'Crossman', 'Bascom', 'Old Ironsides', 'Fruitdale',
#         'Downtown Campbell', 'Whisman', 'Vienna', 'Tasman', 'Race', 'Gish',
#         'River Oaks', 'Mountainview', 'Alder', 'Fair Oaks', 'Moffett Park',
#         'Lockheed Martin', 'Middlefield', 'Reamwood', 'Snell',
#         'Great America', 'Lick Mill', 'Cropley', 'Bayshore/NASA',
#         'Lick Kill', 'Penitencia Creek'], dtype=object))

# %%
# Combine unique values from both ON and OFF stop names and remove duplicates
unique_stop_names = set(unique_on_stop_names).union(set(unique_off_stop_names))

# Convert the set back to a list if needed
unique_stop_names = list(unique_stop_names)

len(unique_stop_names)
# Out:
# 61

# %%
# Old Code

# unique_stop_names=df['STOP_NAME'].unique()
# unique_stop_names

# %%
# unique_stop_names.size

# %%
df.query('LineNameDatabase=="BlueLine"')[code_columns[1:-1]]
# Out:
#       BLUE_LINE_NB_ON_Code_  BLUE_LINE_NB_OFF_Code_  BLUE_LIME_SB_ON_Code_  \
# 1                       1.0                     9.0                    NaN
# 2                       NaN                     NaN                    4.0
# 9                       NaN                     NaN                    2.0
# 10                      NaN                     NaN                    5.0
# 12                      NaN                     NaN                    1.0
# ...                     ...                     ...                    ...
# 6830                   14.0                    17.0                    NaN
# 6831                   14.0                    25.0                    NaN
# 6832                   19.0                    26.0                    NaN
# 6833                   20.0                    25.0                    NaN
# 6834                   22.0                    26.0                    NaN
#
#       BLUE_LIME_SB_OFF_Code_  GREEN_LINE_NB_ON_Code_  GREEN_LINE_NB_OFF_Code_  \
# 1                        NaN                     NaN                      NaN
# 2                        8.0                     NaN                      NaN
# 9                        7.0                     NaN                      NaN
# 10                       8.0                     NaN                      NaN
# 12                      13.0                     NaN                      NaN
# ...                      ...                     ...                      ...
# 6830                     NaN                     NaN                      NaN
# 6831                     NaN                     NaN                      NaN
# 6832                     NaN                     NaN                      NaN
# 6833                     NaN                     NaN                      NaN
# 6834                     NaN                     NaN                      NaN
#
#       GREEN_LINE_SB_ON_Code_  GREEN_LINE_SB_OFF_Code_  \
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 9                        NaN                      NaN
# 10                       NaN                      NaN
# 12                       NaN                      NaN
# ...                      ...                      ...
# 6830                     NaN                      NaN
# 6831                     NaN                      NaN
# 6832                     NaN                      NaN
# 6833                     NaN                      NaN
# 6834                     NaN                      NaN
#
#       ORANGE_LINE_EB_ON_Code_  ORANGE_LINE_EB_OFF_Code_  \
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 9                         NaN                       NaN
# 10                        NaN                       NaN
# 12                        NaN                       NaN
# ...                       ...                       ...
# 6830                      NaN                       NaN
# 6831                      NaN                       NaN
# 6832                      NaN                       NaN
# 6833                      NaN                       NaN
# 6834                      NaN                       NaN
#
#       ORANGE_LINE_WB_ON_Code_  ORANGE_LINE_WB_OFF_Code_
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 9                         NaN                       NaN
# 10                        NaN                       NaN
# 12                        NaN                       NaN
# ...                       ...                       ...
# 6830                      NaN                       NaN
# 6831                      NaN                       NaN
# 6832                      NaN                       NaN
# 6833                      NaN                       NaN
# 6834                      NaN                       NaN
#
# [2588 rows x 12 columns]

# %%
detail_df=detail_df.query('route_short_name.isin(@unique_line_names)')

# %%
detail_df.reset_index(inplace=True,drop=True)

# %%
detail_df.head()
# Out:
#   agency  gtfs_ver gtfs_date route_short_name           route_long_name  \
# 0    VTA         2  8/7/2024         BlueLine  Baypointe - Santa Teresa
# 1    VTA         2  8/7/2024         BlueLine  Baypointe - Santa Teresa
# 2    VTA         2  8/7/2024         BlueLine  Baypointe - Santa Teresa
# 3    VTA         2  8/7/2024         BlueLine  Baypointe - Santa Teresa
# 4    VTA         2  8/7/2024         BlueLine  Baypointe - Santa Teresa
#
#    direction_id   route_dir  seq_fixed  stop_id                 stop_name  \
# 0             0  BlueLine_0          1     4736      Santa Teresa Station
# 1             0  BlueLine_0          2     4737            Cottle Station
# 2             0  BlueLine_0          3     4738             Snell Station
# 3             0  BlueLine_0          4     4739      Blossom Hill Station
# 4             0  BlueLine_0          5     4731  Ohlone-Chynoweth Station
#
#     stop_lat    stop_lon  stop_lat6   stop_lon6             ETC_STOP_ID  \
# 0  37.236668 -121.789141  37.236668 -121.789141  VTA_2_BlueLine_00_4736
# 1  37.242732 -121.803159  37.242732 -121.803159  VTA_2_BlueLine_00_4737
# 2  37.248055 -121.831339  37.248055 -121.831339  VTA_2_BlueLine_00_4738
# 3  37.253150 -121.841811  37.253150 -121.841811  VTA_2_BlueLine_00_4739
# 4  37.257993 -121.859666  37.257993 -121.859666  VTA_2_BlueLine_00_4731
#
#               ETC_STOP_NAME  notes       ETC_ROUTE_ID  \
# 0      Santa Teresa Station    NaN  VTA_2_BlueLine_00
# 1            Cottle Station    NaN  VTA_2_BlueLine_00
# 2             Snell Station    NaN  VTA_2_BlueLine_00
# 3      Blossom Hill Station    NaN  VTA_2_BlueLine_00
# 4  Ohlone-Chynoweth Station    NaN  VTA_2_BlueLine_00
#
#                                       ETC_ROUTE_NAME  LineName
# 0  Blue Line - Baypointe - Santa Teresa [Northbou...  BlueLine
# 1  Blue Line - Baypointe - Santa Teresa [Northbou...  BlueLine
# 2  Blue Line - Baypointe - Santa Teresa [Northbou...  BlueLine
# 3  Blue Line - Baypointe - Santa Teresa [Northbou...  BlueLine
# 4  Blue Line - Baypointe - Santa Teresa [Northbou...  BlueLine

# %%
detail_df.query('route_short_name=="GreenLine" and "Winchester".lower() in ETC_STOP_NAME')
# Out:
# Empty DataFrame
# Columns: [agency, gtfs_ver, gtfs_date, route_short_name, route_long_name, direction_id, route_dir, seq_fixed, stop_id, stop_name, stop_lat, stop_lon, stop_lat6, stop_lon6, ETC_STOP_ID, ETC_STOP_NAME, notes, ETC_ROUTE_ID, ETC_ROUTE_NAME, LineName]
# Index: []

# %%
detail_df.query(
    'LineName == "GreenLine" and '
    'ETC_STOP_NAME.str.lower().str.contains("winchester") and '
    'ETC_ROUTE_ID.str.split("_").str[-1] != "01"', 
    engine='python'
)

# %%
# results = []
# for line_name in unique_line_names:
#     for stop_name in unique_stop_names:
#         # Filter the DataFrame based on the given conditions
#         filtered_df = detail_df.query(
#             f'LineName == "{line_name}" and '
#             f'ETC_STOP_NAME.str.lower().str.contains("{stop_name.lower()}") and '
#             f'ETC_ROUTE_ID.str.split("_").str[-1] != "01"',
#             engine='python'
#         )
#         # If the combination is found, add it to the results
#         if not filtered_df.empty:
#             results.append((line_name, stop_name, filtered_df))

# %%
results = []
for line_name in unique_line_names:
    for stop_name in unique_stop_names:
        # Filter the DataFrame based on the given conditions
        filtered_df = detail_df.query(
            f'LineName == "{line_name}" and '
            f'ETC_STOP_NAME.str.lower().str.contains("{stop_name.lower()}")',
            engine='python'
        )
        # If the combination is found, add it to the results
        if not filtered_df.empty:
            results.append((line_name, stop_name, filtered_df))

# %%
for line_name, stop_name, df in results:
    print(f'Combination found: LineName = {line_name}, StopName = {stop_name}')
    print(df)

# %%
results = []

# Loop through each combination of line name and stop name
for line_name in unique_line_names:
    for stop_name in unique_stop_names:
        # Filter the DataFrame based on the given conditions
#         filtered_df = detail_df.query(
#             f'LineName == "{line_name}" and '
#             f'ETC_STOP_NAME.str.lower().str.contains("{stop_name.lower()}") and '
#             f'ETC_ROUTE_ID.str.split("_").str[-1] != "01"',
#             engine='python'
#         )
        filtered_df = detail_df.query(
            f'LineName == "{line_name}" and '
            f'ETC_STOP_NAME.str.lower().str.contains("{stop_name.lower()}")',
            engine='python'
        )
# If the combination is found, add the relevant data to the results
        if not filtered_df.empty:
            for _, row in filtered_df.iterrows():
                results.append({
                    'STOP_NAME': stop_name,
                    'STOP_ID': row['seq_fixed'],
                    'ETC_STOP_NAME': row['ETC_STOP_NAME'],
                    'note': '',  # Empty column for 'note'
                    'ETC_STOP_ID': row['ETC_STOP_ID'],
                    'ETC_ROUTE_ID': row['ETC_ROUTE_ID'],
                    'ETC_ROUTE_NAME': row['ETC_ROUTE_NAME']
                })

# %%
results_df = pd.DataFrame(results)

# %%
# results_df.to_csv('O2O_STOPS_VTA_02.csv',index=False)
