# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("reviewtool_20240828_DENVER_reviewerstats.xlsx",sheet_name='Route Summary')
df.head()
# Out:
#        Route  Total_Reviews  Total_Removals  Removal_Rate_Percentage  \
# 0  RTD_1_AB1             60               0                 0.000000
# 1  RTD_1_323             18               0                 0.000000
# 2  RTD_1_324             49               1                 2.040816
# 3  RTD_1_208             12               0                 0.000000
# 4  RTD_1_206              1               0                 0.000000
#
#    Route_Reviewed_Percentage Removed_Survey_ids  Sum of Origin Change  \
# 0                        6.0                NaN                    30
# 1                        1.8                NaN                     0
# 2                        4.9              14278                     0
# 3                        1.2                NaN                     0
# 4                        0.1                NaN                     0
#
#    Sum of Destin Change  Sum of NextTrans Change  Sum of PrevTrans Change  \
# ...

# %%
df.columns
# Out:
# Index(['Route', 'Total_Reviews', 'Total_Removals', 'Removal_Rate_Percentage',
#        'Route_Reviewed_Percentage', 'Removed_Survey_ids',
#        'Sum of Origin Change', 'Sum of Destin Change',
#        'Sum of NextTrans Change', 'Sum of PrevTrans Change',
#        'Sum of Record Change', 'Origin Change Percentage',
#        'Destin Change Percentage', 'NextTrans Change Percentage',
#        'PrevTrans Change Percentage', 'Record Change Percentage', 'Row Labels',
#        'Count of Elvis_ID', 'Sum of Origin Change.1', 'Sum of Destin Change.1',
#        'Sum of PrevTrans Change.1', 'Sum of NextTrans Change.1',
#        'Sum of Record Change.1', 'Origin Change Percentage.1',
#        'Destin Change Percentage.1', 'NextTrans Change Percentage.1',
#        'PrevTrans Change Percentage.1', 'Record Change Percentage.1'],
#       dtype='object')

# %%
df[df['Removal_Rate_Percentage']>10][['Route','Total_Reviews','Total_Removals','Removal_Rate_Percentage','Removed_Survey_ids']]
# df[df['Removal_Rate_Percentage']>10][['Route','Total_Reviews','Total_Removals','Removal_Rate_Percentage','Removed_Survey_ids']].to_csv('Route_High_Percentange_Removal.csv',index=False)
# Out:
#        Route  Total_Reviews  Total_Removals  Removal_Rate_Percentage  \
# 7    RTD_1_A            105              12                11.428571
# 13  RTD_1_FF              7               2                28.571429
# 14   RTD_1_N            145              17                11.724138
# 15   RTD_1_G            165              21                12.727273
#
#                                    Removed_Survey_ids
# 7   12328, 12538, 13459, 13474, 13488, 13523, 1353...
# 13                                       12382, 12577
# 14  12569, 12616, 12736, 12805, 12920, 12980, 1302...
# 15  12613, 12672, 12799, 12876, 12878, 13010, 1305...
