# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
detail_df=pd.read_excel('details_TUCSON_AZ_od_excel.xlsx',sheet_name='TOD')
detail_df
# Out:
#                                                                                                                                                                                                                    \
# 0                                                 AM1
# 1                                                 AM2
# 2                                                 AM3
# 3                                                 AM4
# 4                                                MID1
# 5                                                MID2
# 6                                                MID3
# 7                                                MID4
# 8                                                MID5
# 9                                                MID6
# 10                                                PM1
# 11                                                PM2
# 12                                                PM3
# 13                                               OFF1
# 14                                               OFF2
# 15                                               OFF3
# 16                                               OFF4
# 17                                               OFF5
#
#    TIME_ON[Code]              TIME_ON  TIME_PERIOD[Code] TIME_PERIOD  \
# 0            AM1       Before 5:30 am                  1          AM
# 1            AM2    5:30 am - 6:30 am                  1          AM
# 2            AM3    6:30 am - 7:30 am                  1          AM
# 3            AM4    7:30 am - 8:30 am                  1          AM
# 4           MID1    8:30 am - 9:30 am                  2         MID
# 5           MID2   9:30 am - 10:30 am                  2         MID
# 6           MID3  10:30 am - 11:30 am                  2         MID
# 7           MID4  11:30 am - 12:30 pm                  2         MID
# 8           MID5   12:30 pm - 1:30 pm                  2         MID
# 9           MID6    1:30 pm - 2:30 pm                  2         MID
# 10           PM1    2:30 pm - 3:30 pm                  3          PM
# 11           PM2    3:30 pm - 4:30 pm                  3          PM
# 12           PM3    4:30 pm - 5:30 pm                  3          PM
# 13          OFF1    5:30 pm - 6:30 pm                  4         EVE
# 14          OFF2    6:30 pm - 7:30 pm                  4         EVE
# 15          OFF3    7:30 pm - 8:30 pm                  4         EVE
# 16          OFF4    8:30 pm - 9:30 pm                  4         EVE
# 17          OFF5        After 9:30 pm                  4         EVE
#
#    START_TIME  AGENCY                            WKEND_TIME_PERIOD[Code]  \
# 0    04:00:00     NaN                                                ...
# 1    05:00:00     NaN                                                NaN
# 2    06:00:00     NaN                                                NaN
# 3    07:00:00     NaN                                                NaN
# 4    08:00:00     NaN                                                NaN
# 5    09:00:00     NaN                                                NaN
# 6    10:00:00     NaN                                                NaN
# 7    11:00:00     NaN                                                NaN
# 8    12:00:00     NaN                                                NaN
# 9    13:00:00     NaN                                                NaN
# 10   14:00:00     NaN                                                NaN
# 11   15:00:00     NaN                                                NaN
# 12   16:00:00     NaN                                                NaN
# 13   17:00:00     NaN                                                NaN
# 14   18:00:00     NaN                                                NaN
# 15   19:00:00     NaN                                                NaN
# 16   20:00:00     NaN                                                NaN
# 17   21:00:00     NaN                                                NaN
#
#     WKEND_TIME_PERIOD
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN

# %%
detail_df.columns
# Out:
# Index(['                                                                                                                                                                                                              ',
#        'TIME_ON[Code]', 'TIME_ON', 'TIME_PERIOD[Code]', 'TIME_PERIOD',
#        'START_TIME', 'AGENCY', 'WKEND_TIME_PERIOD[Code]', 'WKEND_TIME_PERIOD'],
#       dtype='object')

# %%
detail_df[['TIME_ON[Code]','TIME_ON', 'TIME_PERIOD[Code]']].values
# Out:
# array([['AM1', 'Before 5:30 am', 1],
#        ['AM2', '5:30 am - 6:30 am', 1],
#        ['AM3', '6:30 am - 7:30 am', 1],
#        ['AM4', '7:30 am - 8:30 am', 1],
#        ['MID1', '8:30 am - 9:30 am', 2],
#        ['MID2', '9:30 am - 10:30 am', 2],
#        ['MID3', '10:30 am - 11:30 am', 2],
#        ['MID4', '11:30 am - 12:30 pm', 2],
#        ['MID5', '12:30 pm - 1:30 pm', 2],
#        ['MID6', '1:30 pm - 2:30 pm', 2],
#        ['PM1', '2:30 pm - 3:30 pm', 3],
#        ['PM2', '3:30 pm - 4:30 pm', 3],
#        ['PM3', '4:30 pm - 5:30 pm', 3],
#        ['OFF1', '5:30 pm - 6:30 pm', 4],
#        ['OFF2', '6:30 pm - 7:30 pm', 4],
#        ['OFF3', '7:30 pm - 8:30 pm', 4],
#        ['OFF4', '8:30 pm - 9:30 pm', 4],
#        ['OFF5', 'After 9:30 pm', 4]], dtype=object)
