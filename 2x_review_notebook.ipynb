# %%
import pandas as pd
import numpy as np

import warnings

warnings.filterwarnings('ignore')

# %%
file_name = 'COTA_KINGElvis (3).xlsx'

old_combine_df=pd.read_excel(file_name,sheet_name='Elvis_Review')

new_combine_df=pd.read_csv("Merged Checks.csv")

# %%
old_combine_df.shape,new_combine_df.shape
# Out:
# ((8026, 44), (7054, 43))

# %%
old_combine_df=old_combine_df[old_combine_df['1st Cleaner']!='Test/No 5 MIN']

# %%
old_combine_df.head(5)
# Out:
#    Elvis_Date  elvis_id 1st Cleaner            FINAL_REVIEWER Final_Usage
# 16 2023-11-03      5632     HereAPI         T A Divya, Regina         Use  \
# 17 2023-11-03      5634     HereAPI         T A Divya, Regina         Use
# 18 2023-11-03      5636     HereAPI         T A Divya, Regina         Use
# 19 2023-11-03      5639     HereAPI  T A Divya, Brian, Regina      Remove
# 24 2023-11-03      5646     HereAPI  T A Divya, Brian, Regina         Use
#
#    REASON FOR REMOVAL REASON FOR REMOVAL [Other] route_match_flag
# 16                NaN                                Elvis_Review  \
# 17                NaN                                Elvis_Review
# 18                NaN                                Elvis_Review
# 19         Round trip                                Elvis_Review
# 24                NaN                                Elvis_Review
#
#    distance_flag                                 SUPERVISOR_COMMENT  ...
# 16  Elvis_Review                                                NaN  ...  \
# 17  Elvis_Review                                                NaN  ...
# 18  Elvis_Review                                                NaN  ...
# 19  Elvis_Review                                                NaN  ...
# 24  Elvis_Review  o= home = E Main St & Wilson Ave, Columbus, OH...  ...
#
#     2x_REVIEWED_BY 2x_REVIEWED_FLAG ADMIN_APPROVED SURVEY_RECOVERY
# 16          Regina           Regina            NaN             NaN  \
# 17          Regina           Regina            NaN             NaN
# 18          Regina           Regina            NaN             NaN
# 19          Regina           Regina            NaN             NaN
# 24          Regina           Regina            NaN             NaN
#
#    SURVEY_RECOVERY_REVIEWED_BY  Recovery Check 2x_REVIEWED_BY.1
# 16                         NaN             0.0              NaN  \
# 17                         NaN             0.0              NaN
# 18                         NaN             0.0              NaN
# 19                         NaN             0.0              NaN
# 24                         NaN             0.0              NaN
#
#    2x_REVIEWED_FLAG.1 ADMIN_APPROVED.1 RECORD_INFO
# 16                NaN              NaN         NaN
# 17                NaN              NaN         NaN
# 18                NaN              NaN         NaN
# 19                NaN              NaN         NaN
# 24                NaN              NaN         NaN
#
# [5 rows x 44 columns]

# %%
new_combine_df=new_combine_df[new_combine_df['1st Cleaner']!='Test/No 5 MIN']

# %%
new_combine_df.head(5)
# Out:
#     Elvis_Date  elvis_id 1st Cleaner            FINAL_REVIEWER Final_Usage
# 16  2023-11-03      5632     HereAPI         T A Divya, Regina         Use  \
# 17  2023-11-03      5634     HereAPI         T A Divya, Regina         Use
# 18  2023-11-03      5636     HereAPI         T A Divya, Regina         Use
# 19  2023-11-03      5639     HereAPI  T A Divya, Brian, Regina      Remove
# 24  2023-11-03      5646     HereAPI  T A Divya, Brian, Regina         Use
#
#    REASON FOR REMOVAL REASON FOR REMOVAL [Other] route_match_flag
# 16                NaN                                Elvis_Review  \
# 17                NaN                                Elvis_Review
# 18                NaN                                Elvis_Review
# 19         Round trip                                Elvis_Review
# 24                NaN                                Elvis_Review
#
#    distance_flag                                 SUPERVISOR_COMMENT  ...
# 16  Elvis_Review                                                NaN  ...  \
# 17  Elvis_Review                                                NaN  ...
# 18  Elvis_Review                                                NaN  ...
# 19  Elvis_Review                                                NaN  ...
# 24  Elvis_Review  o= home = E Main St & Wilson Ave, Columbus, OH...  ...
#
#     2x_REVIEWED_FLAG ADMIN_APPROVED SURVEY_RECOVERY
# 16            Regina            NaN             NaN  \
# 17            Regina            NaN             NaN
# 18            Regina            NaN             NaN
# 19            Regina            NaN             NaN
# 24            Regina            NaN             NaN
#
#    SURVEY_RECOVERY_REVIEWED_BY Recovery Check  2x_REVIEWED_BY.1
# 16                         NaN            0.0               NaN  \
# 17                         NaN            0.0               NaN
# 18                         NaN            0.0               NaN
# 19                         NaN            0.0               NaN
# 24                         NaN            0.0               NaN
#
#    2x_REVIEWED_FLAG.1 ADMIN_APPROVED.1 RECORD_INFO 2X_REVIEW_CHECK
# 16                NaN              NaN         NaN               0
# 17                NaN              NaN         NaN               0
# 18                NaN              NaN         NaN               0
# 19                NaN              NaN         NaN               0
# 24                NaN              NaN         NaN               0
#
# [5 rows x 43 columns]

# %%
old_combine_df.head(2)
# Out:
#    Elvis_Date  elvis_id 1st Cleaner     FINAL_REVIEWER Final_Usage
# 16 2023-11-03      5632     HereAPI  T A Divya, Regina         Use  \
# 17 2023-11-03      5634     HereAPI  T A Divya, Regina         Use
#
#    REASON FOR REMOVAL REASON FOR REMOVAL [Other] route_match_flag
# 16                NaN                                Elvis_Review  \
# 17                NaN                                Elvis_Review
#
#    distance_flag SUPERVISOR_COMMENT  ...  2x_REVIEWED_BY 2x_REVIEWED_FLAG
# 16  Elvis_Review                NaN  ...          Regina           Regina  \
# 17  Elvis_Review                NaN  ...          Regina           Regina
#
#    ADMIN_APPROVED SURVEY_RECOVERY SURVEY_RECOVERY_REVIEWED_BY  Recovery Check
# 16            NaN             NaN                         NaN             0.0  \
# 17            NaN             NaN                         NaN             0.0
#
#    2x_REVIEWED_BY.1 2x_REVIEWED_FLAG.1 ADMIN_APPROVED.1 RECORD_INFO
# 16              NaN                NaN              NaN         NaN
# 17              NaN                NaN              NaN         NaN
#
# [2 rows x 44 columns]

# %%
new_combine_df.head(2)
# Out:
#     Elvis_Date  elvis_id 1st Cleaner     FINAL_REVIEWER Final_Usage
# 16  2023-11-03      5632     HereAPI  T A Divya, Regina         Use  \
# 17  2023-11-03      5634     HereAPI  T A Divya, Regina         Use
#
#    REASON FOR REMOVAL REASON FOR REMOVAL [Other] route_match_flag
# 16                NaN                                Elvis_Review  \
# 17                NaN                                Elvis_Review
#
#    distance_flag SUPERVISOR_COMMENT  ...  2x_REVIEWED_FLAG ADMIN_APPROVED
# 16  Elvis_Review                NaN  ...            Regina            NaN  \
# 17  Elvis_Review                NaN  ...            Regina            NaN
#
#    SURVEY_RECOVERY SURVEY_RECOVERY_REVIEWED_BY Recovery Check
# 16             NaN                         NaN            0.0  \
# 17             NaN                         NaN            0.0
#
#     2x_REVIEWED_BY.1 2x_REVIEWED_FLAG.1 ADMIN_APPROVED.1 RECORD_INFO
# 16               NaN                NaN              NaN         NaN  \
# 17               NaN                NaN              NaN         NaN
#
#    2X_REVIEW_CHECK
# 16               0
# 17               0
#
# [2 rows x 43 columns]

# %%
old_combine_df.shape[0],new_combine_df.shape[0]
# Out:
# (6495, 5679)

# %%
if old_combine_df.shape[0] > new_combine_df.shape[0]:
    old_combine_df = pd.merge(old_combine_df, new_combine_df[['id']], on='id', how='inner')


elif old_combine_df.shape[0] < new_combine_df.shape[0]:
    new_combine_df = pd.merge(new_combine_df, old_combine_df[['id']], on='id', how='inner')
    
old_combine_df.drop_duplicates(subset=['id'],inplace=True)
new_combine_df.drop_duplicates(subset=['id'],inplace=True)
# 'else' case is not needed as you are not performing any operation

# If you want to drop the '_merge' and 'Available IDs' columns (if present)
old_combine_df.drop(columns=['_merge'], inplace=True, errors='ignore')
new_combine_df.drop(columns=['_merge'], inplace=True, errors='ignore')

# %%
common_ids = set(old_combine_df['id']).intersection(new_combine_df['id'])
print("Common IDs:", len(common_ids))
# Out:
# Common IDs: 5679

# %%
old_combine_df.shape[0],new_combine_df.shape[0]
# Out:
# (5679, 5679)

# %%
new_combine_df.head()
# Out:
#     Elvis_Date  elvis_id 1st Cleaner            FINAL_REVIEWER Final_Usage
# 16  2023-11-03      5632     HereAPI         T A Divya, Regina         Use  \
# 17  2023-11-03      5634     HereAPI         T A Divya, Regina         Use
# 18  2023-11-03      5636     HereAPI         T A Divya, Regina         Use
# 19  2023-11-03      5639     HereAPI  T A Divya, Brian, Regina      Remove
# 24  2023-11-03      5646     HereAPI  T A Divya, Brian, Regina         Use
#
#    REASON FOR REMOVAL REASON FOR REMOVAL [Other] route_match_flag
# 16                NaN                                Elvis_Review  \
# 17                NaN                                Elvis_Review
# 18                NaN                                Elvis_Review
# 19         Round trip                                Elvis_Review
# 24                NaN                                Elvis_Review
#
#    distance_flag                                 SUPERVISOR_COMMENT  ...
# 16  Elvis_Review                                                NaN  ...  \
# 17  Elvis_Review                                                NaN  ...
# 18  Elvis_Review                                                NaN  ...
# 19  Elvis_Review                                                NaN  ...
# 24  Elvis_Review  o= home = E Main St & Wilson Ave, Columbus, OH...  ...
#
#     2x_REVIEWED_FLAG ADMIN_APPROVED SURVEY_RECOVERY
# 16            Regina            NaN             NaN  \
# 17            Regina            NaN             NaN
# 18            Regina            NaN             NaN
# 19            Regina            NaN             NaN
# 24            Regina            NaN             NaN
#
#    SURVEY_RECOVERY_REVIEWED_BY Recovery Check  2x_REVIEWED_BY.1
# 16                         NaN            0.0               NaN  \
# 17                         NaN            0.0               NaN
# 18                         NaN            0.0               NaN
# 19                         NaN            0.0               NaN
# 24                         NaN            0.0               NaN
#
#    2x_REVIEWED_FLAG.1 ADMIN_APPROVED.1 RECORD_INFO 2X_REVIEW_CHECK
# 16                NaN              NaN         NaN               0
# 17                NaN              NaN         NaN               0
# 18                NaN              NaN         NaN               0
# 19                NaN              NaN         NaN               0
# 24                NaN              NaN         NaN               0
#
# [5 rows x 43 columns]

# %%
new_combine_df.head()
# Out:
#     Elvis_Date  elvis_id 1st Cleaner            FINAL_REVIEWER Final_Usage
# 16  2023-11-03      5632     HereAPI         T A Divya, Regina         Use  \
# 17  2023-11-03      5634     HereAPI         T A Divya, Regina         Use
# 18  2023-11-03      5636     HereAPI         T A Divya, Regina         Use
# 19  2023-11-03      5639     HereAPI  T A Divya, Brian, Regina      Remove
# 24  2023-11-03      5646     HereAPI  T A Divya, Brian, Regina         Use
#
#    REASON FOR REMOVAL REASON FOR REMOVAL [Other] route_match_flag
# 16                NaN                                Elvis_Review  \
# 17                NaN                                Elvis_Review
# 18                NaN                                Elvis_Review
# 19         Round trip                                Elvis_Review
# 24                NaN                                Elvis_Review
#
#    distance_flag                                 SUPERVISOR_COMMENT  ...
# 16  Elvis_Review                                                NaN  ...  \
# 17  Elvis_Review                                                NaN  ...
# 18  Elvis_Review                                                NaN  ...
# 19  Elvis_Review                                                NaN  ...
# 24  Elvis_Review  o= home = E Main St & Wilson Ave, Columbus, OH...  ...
#
#     2x_REVIEWED_FLAG ADMIN_APPROVED SURVEY_RECOVERY
# 16            Regina            NaN             NaN  \
# 17            Regina            NaN             NaN
# 18            Regina            NaN             NaN
# 19            Regina            NaN             NaN
# 24            Regina            NaN             NaN
#
#    SURVEY_RECOVERY_REVIEWED_BY Recovery Check  2x_REVIEWED_BY.1
# 16                         NaN            0.0               NaN  \
# 17                         NaN            0.0               NaN
# 18                         NaN            0.0               NaN
# 19                         NaN            0.0               NaN
# 24                         NaN            0.0               NaN
#
#    2x_REVIEWED_FLAG.1 ADMIN_APPROVED.1 RECORD_INFO 2X_REVIEW_CHECK
# 16                NaN              NaN         NaN               0
# 17                NaN              NaN         NaN               0
# 18                NaN              NaN         NaN               0
# 19                NaN              NaN         NaN               0
# 24                NaN              NaN         NaN               0
#
# [5 rows x 43 columns]

# %%
new_combine_df['2X_REVIEW_CHECK']
# Out:
# 16      0
# 17      0
# 18      0
# 19      0
# 24      0
#        ..
# 7049    0
# 7050    0
# 7051    0
# 7052    0
# 7053    0
# Name: 2X_REVIEW_CHECK, Length: 5679, dtype: int64

# %%
old_combine_df = old_combine_df.sort_values(by='id')
new_combine_df = new_combine_df.sort_values(by='id')

# %%
old_combine_df.reset_index(inplace=True)
new_combine_df.reset_index(inplace=True)

# %%
old_combine_df.head()
# Out:
#    index Elvis_Date  elvis_id 1st Cleaner            FINAL_REVIEWER
# 0      0 2023-11-03      5632     HereAPI         T A Divya, Regina  \
# 1      1 2023-11-03      5634     HereAPI         T A Divya, Regina
# 2      2 2023-11-03      5636     HereAPI         T A Divya, Regina
# 3      3 2023-11-03      5639     HereAPI  T A Divya, Brian, Regina
# 4      4 2023-11-03      5646     HereAPI  T A Divya, Brian, Regina
#
#   Final_Usage REASON FOR REMOVAL REASON FOR REMOVAL [Other] route_match_flag
# 0         Use                NaN                                Elvis_Review  \
# 1         Use                NaN                                Elvis_Review
# 2         Use                NaN                                Elvis_Review
# 3      Remove         Round trip                                Elvis_Review
# 4         Use                NaN                                Elvis_Review
#
#   distance_flag  ... 2x_REVIEWED_BY  2x_REVIEWED_FLAG ADMIN_APPROVED
# 0  Elvis_Review  ...         Regina            Regina            NaN  \
# 1  Elvis_Review  ...         Regina            Regina            NaN
# 2  Elvis_Review  ...         Regina            Regina            NaN
# 3  Elvis_Review  ...         Regina            Regina            NaN
# 4  Elvis_Review  ...         Regina            Regina            NaN
#
#   SURVEY_RECOVERY SURVEY_RECOVERY_REVIEWED_BY Recovery Check
# 0             NaN                         NaN            0.0  \
# 1             NaN                         NaN            0.0
# 2             NaN                         NaN            0.0
# 3             NaN                         NaN            0.0
# 4             NaN                         NaN            0.0
#
#    2x_REVIEWED_BY.1 2x_REVIEWED_FLAG.1 ADMIN_APPROVED.1 RECORD_INFO
# 0               NaN                NaN              NaN         NaN
# 1               NaN                NaN              NaN         NaN
# 2               NaN                NaN              NaN         NaN
# 3               NaN                NaN              NaN         NaN
# 4               NaN                NaN              NaN         NaN
#
# [5 rows x 45 columns]

# %%
new_combine_df.head()
# Out:
#    index  Elvis_Date  elvis_id 1st Cleaner            FINAL_REVIEWER
# 0     16  2023-11-03      5632     HereAPI         T A Divya, Regina  \
# 1     17  2023-11-03      5634     HereAPI         T A Divya, Regina
# 2     18  2023-11-03      5636     HereAPI         T A Divya, Regina
# 3     19  2023-11-03      5639     HereAPI  T A Divya, Brian, Regina
# 4     24  2023-11-03      5646     HereAPI  T A Divya, Brian, Regina
#
#   Final_Usage REASON FOR REMOVAL REASON FOR REMOVAL [Other] route_match_flag
# 0         Use                NaN                                Elvis_Review  \
# 1         Use                NaN                                Elvis_Review
# 2         Use                NaN                                Elvis_Review
# 3      Remove         Round trip                                Elvis_Review
# 4         Use                NaN                                Elvis_Review
#
#   distance_flag  ... 2x_REVIEWED_FLAG  ADMIN_APPROVED SURVEY_RECOVERY
# 0  Elvis_Review  ...           Regina             NaN             NaN  \
# 1  Elvis_Review  ...           Regina             NaN             NaN
# 2  Elvis_Review  ...           Regina             NaN             NaN
# 3  Elvis_Review  ...           Regina             NaN             NaN
# 4  Elvis_Review  ...           Regina             NaN             NaN
#
#   SURVEY_RECOVERY_REVIEWED_BY Recovery Check 2x_REVIEWED_BY.1
# 0                         NaN            0.0              NaN  \
# 1                         NaN            0.0              NaN
# 2                         NaN            0.0              NaN
# 3                         NaN            0.0              NaN
# 4                         NaN            0.0              NaN
#
#    2x_REVIEWED_FLAG.1 ADMIN_APPROVED.1 RECORD_INFO 2X_REVIEW_CHECK
# 0                 NaN              NaN         NaN               0
# 1                 NaN              NaN         NaN               0
# 2                 NaN              NaN         NaN               0
# 3                 NaN              NaN         NaN               0
# 4                 NaN              NaN         NaN               0
#
# [5 rows x 44 columns]

# %%
new_combine_df.loc[0, '2X_REVIEW_CHECK']
# Out:
# 0

# %%
for index , row in old_combine_df.iterrows():
    old_value = row['2X_REVIEW_CHECK']
    new_value = new_combine_df.loc[index, '2X_REVIEW_CHECK']
    
    if old_value != new_value:
        old_combine_df.at[index, '2x_REVIEWED_FLAG'] = new_value
    else:
        old_combine_df.at[index, '2x_REVIEWED_FLAG'] = old_value

# %%
new_combine_df.head()
# Out:
#    index  Elvis_Date  elvis_id 1st Cleaner            FINAL_REVIEWER
# 0     16  2023-11-03      5632     HereAPI         T A Divya, Regina  \
# 1     17  2023-11-03      5634     HereAPI         T A Divya, Regina
# 2     18  2023-11-03      5636     HereAPI         T A Divya, Regina
# 3     19  2023-11-03      5639     HereAPI  T A Divya, Brian, Regina
# 4     24  2023-11-03      5646     HereAPI  T A Divya, Brian, Regina
#
#   Final_Usage REASON FOR REMOVAL REASON FOR REMOVAL [Other] route_match_flag
# 0         Use                NaN                                Elvis_Review  \
# 1         Use                NaN                                Elvis_Review
# 2         Use                NaN                                Elvis_Review
# 3      Remove         Round trip                                Elvis_Review
# 4         Use                NaN                                Elvis_Review
#
#   distance_flag  ... 2x_REVIEWED_FLAG  ADMIN_APPROVED SURVEY_RECOVERY
# 0  Elvis_Review  ...           Regina             NaN             NaN  \
# 1  Elvis_Review  ...           Regina             NaN             NaN
# 2  Elvis_Review  ...           Regina             NaN             NaN
# 3  Elvis_Review  ...           Regina             NaN             NaN
# 4  Elvis_Review  ...           Regina             NaN             NaN
#
#   SURVEY_RECOVERY_REVIEWED_BY Recovery Check 2x_REVIEWED_BY.1
# 0                         NaN            0.0              NaN  \
# 1                         NaN            0.0              NaN
# 2                         NaN            0.0              NaN
# 3                         NaN            0.0              NaN
# 4                         NaN            0.0              NaN
#
#    2x_REVIEWED_FLAG.1 ADMIN_APPROVED.1 RECORD_INFO 2X_REVIEW_CHECK
# 0                 NaN              NaN         NaN               0
# 1                 NaN              NaN         NaN               0
# 2                 NaN              NaN         NaN               0
# 3                 NaN              NaN         NaN               0
# 4                 NaN              NaN         NaN               0
#
# [5 rows x 44 columns]
